# %%
import matplotlib.pyplot as plt
plt.style.use('bmh')
mu = 70
variance = 200
sigma = math.sqrt(variance)
x = np.linspace(mu - 3*sigma, mu + 3*sigma, 1000)
plt.plot(x, mlab.normpdf(x, mu, sigma))
plt.show()

# %%
mu = 735
# variance = 1500.0
sigma = 105.0
x = np.linspace(mu - 3*sigma, mu + 3*sigma, 10000)
plt.plot(x, mlab.normpdf(x, mu, sigma))
plt.show()

# %%
mu = 2.4
# variance = 1500.0
sigma = 2.0
x = np.linspace(0, mu + 3*sigma, 10000)
plt.plot(x, mlab.normpdf(x, mu, sigma))
plt.show()

# %%
# https://www.khanacademy.org/math/statistics-probability/sampling-distributions-library/sample-means/v/sampling-distribution-example-problem

def cumulative_normal_dist(mu, sig, x):
    return 1/2*(1 + math.erf((x-mu)/(sig*math.sqrt(2))))

print(1 - cumulative_normal_dist(2, 0.099, 2.2))
print(cumulative_normal_dist(2, 0.099, 2.2))
# Out:
# 0.021681218415019687
# 0.9783187815849803
